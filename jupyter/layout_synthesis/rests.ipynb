# %% [markdown]
# # Rests
#
# This notebooks tests the rendering of rests.
#
# Measures:
# 1. Measure rests
# 2. Whole rests
# 3. Half to sixteenth rests
# 4. Dotted rests (TODO)
# 5. Display pitch (for both the G and F clefs)
# 6. Display pitch for whole rests
# 7. Signle ledger line for whole and half rests
# 8. Multiple voices, no ledger line for quarter notes

# %%
# %load_ext autoreload
# %autoreload 2
# %env MC_ASSETS_CACHE=../../mashcima_assets

# %%
import cv2
from IPython.display import Image
from mashcima2.orchestration.BaseHandwrittenModel import BaseHandwrittenModel

model = BaseHandwrittenModel()
bitmap = model("rests.musicxml")
Image(data=cv2.imencode(".png", bitmap)[1], width=900)
