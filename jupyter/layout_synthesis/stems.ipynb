# %% [markdown]
# # Stems
#
# This notebooks tests the rendering of stems.
#
# Measures:
# 1. no stem, simple half note stems
# 2. double stem, few chords

# %%
# %load_ext autoreload
# %autoreload 2
# %env MC_ASSETS_CACHE=../../smashcima_assets

# %%
import cv2
from IPython.display import Image
from smashcima.orchestration.BaseHandwrittenModel import BaseHandwrittenModel

model = BaseHandwrittenModel()
bitmap = model("stems.musicxml")
Image(data=cv2.imencode(".png", bitmap)[1], width=900)
